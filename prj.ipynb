# %%
# %% [markdown]
# # Analisis Tingkat Kemiskinan di Indonesia
# Dataset ini berisi indikator sosial-ekonomi tingkat kabupaten/kota di Indonesia dengan klasifikasi kemiskinan sebagai target (0 = tidak miskin, 1 = miskin).

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (classification_report, 
                           confusion_matrix, 
                           accuracy_score,
                           RocCurveDisplay,
                           PrecisionRecallDisplay)
from imblearn.over_sampling import SMOTE
import joblib

# %% [markdown]
# ## 2. Load dan Pembersihan Data

# %%
# Load data dengan delimiter titik koma
df = pd.read_csv('Klasifikasi Tingkat Kemiskinan di Indonesia.csv', 
                 sep=';', 
                 decimal=',', 
                 thousands='.')

# Hapus baris kosong
df = df.dropna(how='all')

# Pengecekan data awal
print("\nJumlah missing values per kolom:")
print(df.isnull().sum())

# Konversi koma ke titik untuk kolom numerik dan handle missing values
numeric_cols = [
    'Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)',
    'Rata-rata Lama Sekolah Penduduk 15+ (Tahun)',
    'Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)',
    'Indeks Pembangunan Manusia',
    'Umur Harapan Hidup (Tahun)',
    'Persentase rumah tangga yang memiliki akses terhadap sanitasi layak',
    'Persentase rumah tangga yang memiliki akses terhadap air minum layak',
    'Tingkat Pengangguran Terbuka',
    'Tingkat Partisipasi Angkatan Kerja',
    'PDRB atas Dasar Harga Konstan menurut Pengeluaran (Rupiah)'
]

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(',', '.'), errors='coerce')

# Hapus baris dengan missing values
df = df.dropna(subset=numeric_cols)

# %% [markdown]
# ## 3. Eksplorasi Data

# %%
# Tampilkan struktur data
print(f"\nJumlah baris: {df.shape[0]}, Jumlah kolom: {df.shape[1]}")
print("\n5 baris pertama data:")
display(df.head())

# %%
# Statistik deskriptif
print("\nStatistik Deskriptif:")
display(df[numeric_cols].describe().T)

# %%
# Distribusi kelas target
plt.figure(figsize=(8, 6))
sns.countplot(x='Klasifikasi Kemiskinan', data=df)
plt.title('Distribusi Klasifikasi Kemiskinan')
plt.xlabel('Klasifikasi (0: Tidak Miskin, 1: Miskin)')
plt.ylabel('Jumlah Kabupaten/Kota')
plt.show()

# Distribusi fitur numerik - Figure 1 (6 plot pertama)
plt.figure(figsize=(20, 12))
for i, col in enumerate(numeric_cols[:6], 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(col, pad=12, fontsize=12)
    plt.xticks(rotation=45, fontsize=10)
    plt.yticks(fontsize=10)
    plt.xlabel('Nilai', fontsize=10)
    plt.ylabel('Frekuensi', fontsize=10)
plt.tight_layout(pad=4.0)
plt.show()

# Distribusi fitur numerik - Figure 2 (6 plot berikutnya)
plt.figure(figsize=(20, 12))
for i, col in enumerate(numeric_cols[6:], 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(col, pad=12, fontsize=12)
    plt.xticks(rotation=45, fontsize=10)
    plt.yticks(fontsize=10)
    plt.xlabel('Nilai', fontsize=10)
    plt.ylabel('Frekuensi', fontsize=10)
plt.tight_layout(pad=4.0)
plt.show()

# %%
# Korelasi antar fitur
plt.figure(figsize=(12, 10))
corr_matrix = df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Korelasi Antar Variabel Numerik')
plt.show()

# %% [markdown]
# ## 4. Visualisasi Kunci

# %%
# Hubungan kemiskinan dengan pengeluaran per kapita
plt.figure(figsize=(10, 6))
sns.boxplot(x='Klasifikasi Kemiskinan', 
            y='Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)', 
            data=df)
plt.title('Distribusi Pengeluaran per Kapita berdasarkan Klasifikasi Kemiskinan')
plt.xlabel('Klasifikasi Kemiskinan')
plt.ylabel('Pengeluaran per Kapita (Ribu Rupiah/Tahun)')
plt.show()

# %%
# Scatter plot pendidikan vs kemiskinan
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='Rata-rata Lama Sekolah Penduduk 15+ (Tahun)',
    y='Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)',
    hue='Klasifikasi Kemiskinan',
    data=df,
    alpha=0.7
)
plt.title('Hubungan Pendidikan dan Tingkat Kemiskinan')
plt.xlabel('Rata-rata Lama Sekolah (Tahun)')
plt.ylabel('Persentase Penduduk Miskin (%)')
plt.show()

# %%
# Top 10 daerah dengan kemiskinan tertinggi (sudah diperbaiki)
top_miskin = df.sort_values('Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)', 
                          ascending=False).head(10)
plt.figure(figsize=(12, 8))
sns.barplot(
    x='Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)',
    y='Kab/Kota',
    data=top_miskin,
    hue='Kab/Kota',
    palette='Reds_d',
    legend=False,
    dodge=False
)
plt.title('10 Kabupaten/Kota dengan Tingkat Kemiskinan Tertinggi')
plt.xlabel('Persentase Penduduk Miskin (%)')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## 5. Pemodelan Klasifikasi

# %%
# Persiapan data
X = df[numeric_cols]
y = df['Klasifikasi Kemiskinan']

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Normalisasi fitur
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Handle class imbalance dengan SMOTE
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

# %%
# Tuning hyperparameter dengan GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid, 
    cv=5, 
    scoring='accuracy',
    n_jobs=-1
)
grid_search.fit(X_train_smote, y_train_smote)

best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)

# %%
# Prediksi dan evaluasi
y_pred = best_model.predict(X_test_scaled)

print("\nAkurasi:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Matriks konfusi
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=['Tidak Miskin', 'Miskin'],
            yticklabels=['Tidak Miskin', 'Miskin'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# ROC Curve
RocCurveDisplay.from_estimator(best_model, X_test_scaled, y_test)
plt.title('ROC Curve')
plt.show()

# Precision-Recall Curve
PrecisionRecallDisplay.from_estimator(best_model, X_test_scaled, y_test)
plt.title('Precision-Recall Curve')
plt.show()

# %%
# Feature importance
feature_importance = pd.Series(best_model.feature_importances_, 
                             index=numeric_cols)
plt.figure(figsize=(10, 6))
feature_importance.nlargest(10).plot(kind='barh')
plt.title('Feature Importance')
plt.xlabel('Importance Score')
plt.show()

# %% [markdown]
# ## 6. Simpan Hasil Analisis

# %%
# Tambahkan prediksi ke dataframe
df['Prediksi'] = best_model.predict(scaler.transform(X))

# Simpan hasil analisis
df.to_csv('hasil_klasifikasi_kemiskinan.csv', index=False)

# Simpan model dan scaler
joblib.dump(best_model, 'model_kemiskinan.pkl')
joblib.dump(scaler, 'scaler_kemiskinan.pkl')

print("\nAnalisis selesai. Model dan hasil telah disimpan.")
# Out:
# Jumlah missing values per kolom:
# Provinsi                                                                0
# Kab/Kota                                                                0
# Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)         0
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)                             0
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)            0
# Indeks Pembangunan Manusia                                              0
# Umur Harapan Hidup (Tahun)                                              0
# Persentase rumah tangga yang memiliki akses terhadap sanitasi layak     0
# Persentase rumah tangga yang memiliki akses terhadap air minum layak    0
# Tingkat Pengangguran Terbuka                                            0
# Tingkat Partisipasi Angkatan Kerja                                      0
# PDRB atas Dasar Harga Konstan menurut Pengeluaran (Rupiah)              0
# Klasifikasi Kemiskinan                                                  0
# dtype: int64
#
# Jumlah baris: 514, Jumlah kolom: 13
#
# 5 baris pertama data:
#   Provinsi       Kab/Kota  \
# 0     ACEH       Simeulue
# 1     ACEH   Aceh Singkil
# 2     ACEH   Aceh Selatan
# 3     ACEH  Aceh Tenggara
# 4     ACEH     Aceh Timur
#
#    Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)  \
# 0                                              18.98
# 1                                              20.36
# 2                                              13.18
# 3                                              13.41
# 4                                              14.45
#
#    Rata-rata Lama Sekolah Penduduk 15+ (Tahun)  \
# 0                                         9.48
# 1                                         8.68
# 2                                         8.88
# 3                                         9.67
# 4                                         8.21
#
#    Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)  \
# 0                                             7148.0
# 1                                             8776.0
# 2                                             8180.0
# 3                                             8030.0
# 4                                             8577.0
#
#    Indeks Pembangunan Manusia  Umur Harapan Hidup (Tahun)  \
# 0                       66.41                       65.28
# 1                       69.22                       67.43
# 2                       67.44                       64.40
# 3                       69.44                       68.22
# 4                       67.83                       68.74
#
#    Persentase rumah tangga yang memiliki akses terhadap sanitasi layak  \
# 0                                              71.56
# 1                                              69.56
# 2                                              62.55
# 3                                              62.71
# 4                                              66.75
#
#    Persentase rumah tangga yang memiliki akses terhadap air minum layak  \
# 0                                              87.45
# 1                                              78.58
# 2                                              79.65
# 3                                              86.71
# 4                                              83.16
#
#    Tingkat Pengangguran Terbuka  Tingkat Partisipasi Angkatan Kerja  \
# 0                          5.71                               71.15
# 1                          8.36                               62.85
# 2                          6.46                               60.85
# 3                          6.43                               69.62
# 4                          7.13                               59.48
#
#    PDRB atas Dasar Harga Konstan menurut Pengeluaran (Rupiah)  \
# 0                                          1648096.0
# 1                                          1780419.0
# 2                                          4345784.0
# 3                                          3487157.0
# 4                                          8433526.0
#
#    Klasifikasi Kemiskinan
# 0                     0.0
# 1                     1.0
# 2                     0.0
# 3                     0.0
# 4                     0.0
# Statistik Deskriptif:
#                                                     count          mean  \
# Persentase Penduduk Miskin (P0) Menurut Kabupat...  514.0  1.519115e+01
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)         514.0  1.208151e+02
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...  514.0  1.032479e+04
# Indeks Pembangunan Manusia                          514.0  6.992677e+01
# Umur Harapan Hidup (Tahun)                          514.0  6.965681e+01
# Persentase rumah tangga yang memiliki akses ter...  514.0  7.720224e+01
# Persentase rumah tangga yang memiliki akses ter...  514.0  8.513661e+01
# Tingkat Pengangguran Terbuka                        514.0  5.059494e+00
# Tingkat Partisipasi Angkatan Kerja                  514.0  6.946446e+01
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  514.0  2.196408e+07
#
#                                                              std        min  \
# Persentase Penduduk Miskin (P0) Menurut Kabupat...  4.783340e+01       2.38
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)         2.897872e+02       1.42
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...  2.717144e+03    3976.00
# Indeks Pembangunan Manusia                          6.497033e+00      32.84
# Umur Harapan Hidup (Tahun)                          3.447464e+00      55.43
# Persentase rumah tangga yang memiliki akses ter...  1.858355e+01       0.00
# Persentase rumah tangga yang memiliki akses ter...  1.570166e+01       0.00
# Tingkat Pengangguran Terbuka                        2.636970e+00       0.00
# Tingkat Partisipasi Angkatan Kerja                  6.396405e+00      56.39
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  4.790492e+07  147485.00
#
#                                                              25%          50%  \
# Persentase Penduduk Miskin (P0) Menurut Kabupat...  7.155000e+00       10.545
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)         7.712500e+00        8.585
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...  8.574000e+03    10196.500
# Indeks Pembangunan Manusia                          6.664250e+01       69.610
# Umur Harapan Hidup (Tahun)                          6.738750e+01       69.975
# Persentase rumah tangga yang memiliki akses ter...  7.021750e+01       81.800
# Persentase rumah tangga yang memiliki akses ter...  7.904250e+01       89.795
# Tingkat Pengangguran Terbuka                        3.180000e+00        4.565
# Tingkat Partisipasi Angkatan Kerja                  6.507000e+01       68.955
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  3.654292e+06  8814925.500
#
#                                                              75%           max
# Persentase Penduduk Miskin (P0) Menurut Kabupat...  1.500750e+01  8.970000e+02
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)         1.033750e+01  1.182000e+03
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...  1.171900e+04  2.388800e+04
# Indeks Pembangunan Manusia                          7.311250e+01  8.718000e+01
# Umur Harapan Hidup (Tahun)                          7.204250e+01  7.773000e+01
# Persentase rumah tangga yang memiliki akses ter...  8.988250e+01  9.997000e+01
# Persentase rumah tangga yang memiliki akses ter...  9.640000e+01  1.000000e+02
# Tingkat Pengangguran Terbuka                        6.530000e+00  1.337000e+01
# Tingkat Partisipasi Angkatan Kerja                  7.234250e+01  9.793000e+01
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  1.973510e+07  4.600810e+08
# Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 50}
#
# Akurasi: 0.9870967741935484
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99       136
#          1.0       0.90      1.00      0.95        19
#
#     accuracy                           0.99       155
#    macro avg       0.95      0.99      0.97       155
# weighted avg       0.99      0.99      0.99       155
# Analisis selesai. Model dan hasil telah disimpan.
