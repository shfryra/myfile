# %%
# %% [markdown]
# # Analisis Tingkat Kemiskinan di Indonesia

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (classification_report, 
                             confusion_matrix, 
                             accuracy_score,
                             RocCurveDisplay,
                             PrecisionRecallDisplay)
from imblearn.over_sampling import SMOTE
import joblib

# %% [markdown]
# ## 2. Load dan Pembersihan Data

# %%
# Membaca data dengan separator titik koma
df = pd.read_csv('Klasifikasi Tingkat Kemiskinan di Indonesia.csv', sep=';')

# Membersihkan data
df = df.dropna(how='all')  # Hapus baris yang seluruhnya kosong
df = df.replace(',', '.', regex=True)  # Ganti koma dengan titik untuk desimal

# Kolom numerik yang akan digunakan
numeric_cols = [
    'Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)',
    'Rata-rata Lama Sekolah Penduduk 15+ (Tahun)',
    'Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)',
    'Indeks Pembangunan Manusia',
    'Umur Harapan Hidup (Tahun)',
    'Persentase rumah tangga yang memiliki akses terhadap sanitasi layak',
    'Persentase rumah tangga yang memiliki akses terhadap air minum layak',
    'Tingkat Pengangguran Terbuka',
    'Tingkat Partisipasi Angkatan Kerja',
    'PDRB atas Dasar Harga Konstan menurut Pengeluaran (Rupiah)'
]

# Konversi ke tipe data numerik
for col in numeric_cols:
    # Menghapus titik sebagai pemisah ribuan dan mengubah koma menjadi titik untuk desimal
    df[col] = df[col].astype(str).str.replace('.', '', regex=False)
    df[col] = df[col].str.replace(',', '.', regex=False)
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Hapus baris dengan nilai kosong di kolom numerik
df = df.dropna(subset=numeric_cols)

# Kolom target
target_col = 'Klasifikasi Kemiskinan'

# %% [markdown]
# ## 3. Eksplorasi Data

# %%
print(f"\nJumlah baris: {df.shape[0]}, Jumlah kolom: {df.shape[1]}")
print("\n5 data teratas:")
display(df.head())

# %%
print("\nStatistik Deskriptif:")
display(df[numeric_cols].describe().T)

# %%
# Distribusi klasifikasi kemiskinan
plt.figure(figsize=(8, 6))
sns.countplot(x=target_col, data=df)
plt.title('Distribusi Klasifikasi Kemiskinan')
plt.xlabel('Klasifikasi (0: Tidak Miskin, 1: Miskin)')
plt.ylabel('Jumlah Kabupaten/Kota')
plt.show()

# Distribusi variabel numerik
plt.figure(figsize=(20, 15))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(4, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.tight_layout()
plt.show()

# %%
# Matriks korelasi
plt.figure(figsize=(12, 10))
corr_matrix = df[numeric_cols].corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Korelasi Antar Variabel Numerik')
plt.show()

# %% [markdown]
# ## 4. Visualisasi Kunci

# %%
# Distribusi pengeluaran per kapita
plt.figure(figsize=(10, 6))
sns.boxplot(x=target_col, 
            y='Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)', 
            data=df)
plt.title('Distribusi Pengeluaran per Kapita berdasarkan Klasifikasi Kemiskinan')
plt.show()

# %%
# Hubungan pendidikan dan kemiskinan
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='Rata-rata Lama Sekolah Penduduk 15+ (Tahun)',
    y='Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)',
    hue=target_col,
    data=df,
    alpha=0.7
)
plt.title('Hubungan Pendidikan dan Tingkat Kemiskinan')
plt.show()

# %%
# 10 daerah termiskin
top_miskin = df.sort_values('Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)', 
                          ascending=False).head(10)
plt.figure(figsize=(12, 8))
sns.barplot(
    x='Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)',
    y='Kab/Kota',
    data=top_miskin,
    palette='Reds_d'
)
plt.title('10 Kabupaten/Kota dengan Tingkat Kemiskinan Tertinggi')
plt.show()

# %% [markdown]
# ## 5. Pemodelan Klasifikasi

# %%
# Persiapan data
X = df[numeric_cols]
y = df[target_col]

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Normalisasi
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Penanganan data tidak seimbang
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

# %%
# Pelatihan model dengan GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid, 
    cv=5, 
    scoring='f1',  # Menggunakan f1 karena data tidak seimbang
    n_jobs=-1
)
grid_search.fit(X_train_smote, y_train_smote)

best_model = grid_search.best_estimator_
print("Parameter terbaik:", grid_search.best_params_)

# %%
# Evaluasi model
y_pred = best_model.predict(X_test_scaled)

print("\nAkurasi:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=['Tidak Miskin', 'Miskin'],
            yticklabels=['Tidak Miskin', 'Miskin'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# ROC Curve
RocCurveDisplay.from_estimator(best_model, X_test_scaled, y_test)
plt.title('ROC Curve')
plt.show()

# Precision-Recall Curve
PrecisionRecallDisplay.from_estimator(best_model, X_test_scaled, y_test)
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ## 6. Feature Importance

# %%
# Analisis kepentingan fitur
feature_importance = pd.Series(best_model.feature_importances_, index=numeric_cols)
feature_importance_df = feature_importance.sort_values(ascending=False).reset_index()
feature_importance_df.columns = ['Fitur', 'Skor Importance']

plt.figure(figsize=(10, 6))
sns.barplot(x='Skor Importance', y='Fitur', data=feature_importance_df, palette='viridis')
plt.title('Kepentingan Fitur dalam Model Random Forest')
plt.xlabel('Skor Kepentingan')
plt.ylabel('Fitur')
plt.tight_layout()
plt.show()

# Simpan hasil analisis fitur
feature_importance_df.to_csv('feature_importance_kemiskinan.csv', index=False)

# %% [markdown]
# ## 7. Simpan Hasil Analisis

# %%
# Simpan prediksi dan model
df['Prediksi'] = best_model.predict(scaler.transform(X))
df.to_csv('hasil_klasifikasi_kemiskinan.csv', index=False)

joblib.dump(best_model, 'model_kemiskinan.pkl')
joblib.dump(scaler, 'scaler_kemiskinan.pkl')

print("\nAnalisis selesai. Model, scaler, dan hasil prediksi telah disimpan.")
# Out:
# Jumlah baris: 514, Jumlah kolom: 13
#
# 5 data teratas:
#   Provinsi       Kab/Kota  \
# 0     ACEH       Simeulue
# 1     ACEH   Aceh Singkil
# 2     ACEH   Aceh Selatan
# 3     ACEH  Aceh Tenggara
# 4     ACEH     Aceh Timur
#
#    Persentase Penduduk Miskin (P0) Menurut Kabupaten/Kota (Persen)  \
# 0                                               1898
# 1                                               2036
# 2                                               1318
# 3                                               1341
# 4                                               1445
#
#    Rata-rata Lama Sekolah Penduduk 15+ (Tahun)  \
# 0                                          948
# 1                                          868
# 2                                          888
# 3                                          967
# 4                                          821
#
#    Pengeluaran per Kapita Disesuaikan (Ribu Rupiah/Orang/Tahun)  \
# 0                                              71480
# 1                                              87760
# 2                                              81800
# 3                                              80300
# 4                                              85770
#
#    Indeks Pembangunan Manusia  Umur Harapan Hidup (Tahun)  \
# 0                        6641                        6528
# 1                        6922                        6743
# 2                        6744                         644
# 3                        6944                        6822
# 4                        6783                        6874
#
#    Persentase rumah tangga yang memiliki akses terhadap sanitasi layak  \
# 0                                               7156
# 1                                               6956
# 2                                               6255
# 3                                               6271
# 4                                               6675
#
#    Persentase rumah tangga yang memiliki akses terhadap air minum layak  \
# 0                                               8745
# 1                                               7858
# 2                                               7965
# 3                                               8671
# 4                                               8316
#
#    Tingkat Pengangguran Terbuka  Tingkat Partisipasi Angkatan Kerja  \
# 0                           571                                7115
# 1                           836                                6285
# 2                           646                                6085
# 3                           643                                6962
# 4                           713                                5948
#
#    PDRB atas Dasar Harga Konstan menurut Pengeluaran (Rupiah)  \
# 0                                           16480960
# 1                                           17804190
# 2                                           43457840
# 3                                           34871570
# 4                                           84335260
#
#    Klasifikasi Kemiskinan
# 0                     0.0
# 1                     1.0
# 2                     0.0
# 3                     0.0
# 4                     0.0
# Statistik Deskriptif:
#                                                     count          mean  \
# Persentase Penduduk Miskin (P0) Menurut Kabupat...  514.0  1.119158e+03
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)         514.0  7.553074e+02
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...  514.0  1.032479e+05
# Indeks Pembangunan Manusia                          514.0  6.226714e+03
# Umur Harapan Hidup (Tahun)                          514.0  6.371173e+03
# Persentase rumah tangga yang memiliki akses ter...  514.0  7.720224e+03
# Persentase rumah tangga yang memiliki akses ter...  514.0  8.513661e+03
# Tingkat Pengangguran Terbuka                        514.0  5.059494e+02
# Tingkat Partisipasi Angkatan Kerja                  514.0  6.946446e+03
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  514.0  2.196408e+08
#
#                                                              std        min  \
# Persentase Penduduk Miskin (P0) Menurut Kabupat...  7.761768e+02        9.0
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)         2.893177e+02        7.0
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...  2.717144e+04    39760.0
# Indeks Pembangunan Manusia                          2.149087e+03       55.0
# Umur Harapan Hidup (Tahun)                          1.882185e+03       58.0
# Persentase rumah tangga yang memiliki akses ter...  1.858355e+03        0.0
# Persentase rumah tangga yang memiliki akses ter...  1.570166e+03        0.0
# Tingkat Pengangguran Terbuka                        2.636970e+02        0.0
# Tingkat Partisipasi Angkatan Kerja                  6.396405e+02     5639.0
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  4.790492e+08  1474850.0
#
#                                                             25%         50%  \
# Persentase Penduduk Miskin (P0) Menurut Kabupat...       592.25       965.0
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)              711.00       811.5
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...     85740.00    101965.0
# Indeks Pembangunan Manusia                              6541.25      6899.0
# Umur Harapan Hidup (Tahun)                              6645.25      6940.5
# Persentase rumah tangga yang memiliki akses ter...      7021.75      8180.0
# Persentase rumah tangga yang memiliki akses ter...      7904.25      8979.5
# Tingkat Pengangguran Terbuka                             318.00       456.5
# Tingkat Partisipasi Angkatan Kerja                      6507.00      6895.5
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  36542915.00  88149255.0
#
#                                                              75%           max
# Persentase Penduduk Miskin (P0) Menurut Kabupat...  1.425750e+03  4.166000e+03
# Rata-rata Lama Sekolah Penduduk 15+ (Tahun)         9.140000e+02  1.283000e+03
# Pengeluaran per Kapita Disesuaikan (Ribu Rupiah...  1.171900e+05  2.388800e+05
# Indeks Pembangunan Manusia                          7.233000e+03  8.718000e+03
# Umur Harapan Hidup (Tahun)                          7.172000e+03  7.773000e+03
# Persentase rumah tangga yang memiliki akses ter...  8.988250e+03  9.997000e+03
# Persentase rumah tangga yang memiliki akses ter...  9.640000e+03  1.000000e+04
# Tingkat Pengangguran Terbuka                        6.530000e+02  1.337000e+03
# Tingkat Partisipasi Angkatan Kerja                  7.234250e+03  9.793000e+03
# PDRB atas Dasar Harga Konstan menurut Pengeluar...  1.973510e+08  4.600810e+09
# C:\Users\user\AppData\Local\Temp\ipykernel_10744\206891988.py:129: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Parameter terbaik: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 50}
#
# Akurasi: 0.9806451612903225
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99       136
#          1.0       0.90      0.95      0.92        19
#
#     accuracy                           0.98       155
#    macro avg       0.95      0.97      0.96       155
# weighted avg       0.98      0.98      0.98       155
# C:\Users\user\AppData\Local\Temp\ipykernel_10744\206891988.py:221: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Skor Importance', y='Fitur', data=feature_importance_df, palette='viridis')
# Analisis selesai. Model, scaler, dan hasil prediksi telah disimpan.
